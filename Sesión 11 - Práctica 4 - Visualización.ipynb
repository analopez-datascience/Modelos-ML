# %% [markdown]
# # Visualización

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Utilizamos la función linspace que nos genera 30 datos aleatorios entre 0 y 100.

# %%
a = np.linspace(0, 100,30) 
print(a)
# Out:
# [  0.           3.44827586   6.89655172  10.34482759  13.79310345
#   17.24137931  20.68965517  24.13793103  27.5862069   31.03448276
#   34.48275862  37.93103448  41.37931034  44.82758621  48.27586207
#   51.72413793  55.17241379  58.62068966  62.06896552  65.51724138
#   68.96551724  72.4137931   75.86206897  79.31034483  82.75862069
#   86.20689655  89.65517241  93.10344828  96.55172414 100.        ]

# %%
# Draw the plot
plt.plot(a, 2*a + 15)

# Add X Label on X-axis
plt.xlabel("X-label")

# Add X Label on X-axis
plt.ylabel("Y-label")

# Display the chart
plt.show()

# %%
x = [1,3,5,7,9,11]
y = [10,25,35,33,41,59]

# Let's plot the data
plt.plot(x, y,label='Series-1', color='pink')

# Add X Label on X-axis
plt.xlabel("X-label")

# Add X Label on X-axis
plt.ylabel("Y-label")

# Add legend to graph
plt.legend()

# %%
x = [1,3,5,7,9,11]
y = [10,25,35,33,41,59]

# Let's plot the data
plt.plot(x, y,label='Series-1', color='blue')


# Create the data
x = [2,4,6,8,10,12]
y = [15,29,32,33,38,55]

# Plot the data
plt.plot(x, y, label='Series-2', color='pink')


# Add X Label on X-axis
plt.xlabel("X-label")

# Add X Label on X-axis
plt.ylabel("Y-label")

# Append the title to graph
plt.title("Multiple Python Line Graph")

# Add legend to graph
plt.legend()

# Display the plot
plt.show()

# %%
data = pd.read_csv("./Advertising.csv")
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %% [markdown]
# # Gráfico de líneas

# %%
# Let's plot the data
plt.plot(data.Radio, data.Sales,label='Series-1', color='pink')

# Add X Label on X-axis
plt.xlabel("X-label")

# Add X Label on X-axis
plt.ylabel("Y-label")

# Add legend to graph
plt.legend()

plt.title("Ventas según radio")
# Out:
# Text(0.5, 1.0, 'Ventas según radio')

# %% [markdown]
# # Scatter Plot

# %%
plt.scatter(data.Radio, data.Sales, c='pink', marker='*',alpha=0.5)

# Append the label on X-axis
plt.xlabel("X-Radio")
 
# Append the label on X-axis
plt.ylabel("Y-Sales")

# Add the title to graph
plt.title("Scatter Chart Sample")
 
# Display the chart
plt.show()

# %%
a
# Out:
# array([  0.        ,   3.44827586,   6.89655172,  10.34482759,
#         13.79310345,  17.24137931,  20.68965517,  24.13793103,
#         27.5862069 ,  31.03448276,  34.48275862,  37.93103448,
#         41.37931034,  44.82758621,  48.27586207,  51.72413793,
#         55.17241379,  58.62068966,  62.06896552,  65.51724138,
#         68.96551724,  72.4137931 ,  75.86206897,  79.31034483,
#         82.75862069,  86.20689655,  89.65517241,  93.10344828,
#         96.55172414, 100.        ])

# %%
plt.scatter(data.Radio, data.Sales, c='pink', marker='*',alpha=0.5)

plt.plot(a, 0.19*a + 2.9)

# Append the label on X-axis
plt.xlabel("X-Radio")
 
# Append the label on X-axis
plt.ylabel("Y-Sales")

# Add the title to graph
plt.title("Scatter Chart Sample")

# Display the chart
plt.show()

# %%
data.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %% [markdown]
# # Pie Plot

# %%
subjects = ["Mathematics","Science","Communication Skills","Computer Application"]
scores = [85,62,57,92]

# Plot the pie plot
plt.pie(scores,
        labels=subjects,
        colors=['r','g','b','y'],
        startangle=90,
        shadow= True,
        explode=(0,0.2,0.1,0), 
        autopct='%1.1f%%')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
subjects = ["Mathematics","Science","Communication Skills","Computer Application"]
scores = [70,30,20,40]

# Plot the pie plot
plt.pie(scores,
        labels=subjects,
        colors=['pink','blue','red','black'],
        startangle=90,
        shadow= False,
        explode=(0,0,0.1,0), 
        autopct='%1.1f%%')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Bar Plot
#
# Nos permite definir los ratings en función de diferentes observaciones.

# %% [markdown]
# # Bubble Plot
# Nos permite introducir tres dimensiones, visualizando así un 3d sobre un plano.

# %%
plt.figure(figsize=(8,5))

# Create the data
countries = ['Qatar','Luxembourg','Singapore','Brunei','Ireland','Norway','UAE','Kuwait']
populations = [2781682, 604245,5757499,428963,4818690,5337962,9630959,4137312]
gdp_per_capita = [130475, 106705, 100345, 79530, 78785, 74356,69382, 67000]

# scale GDP per capti income to shot the bubbles in the graph
scaled_gdp_per_capita  = np.divide(gdp_per_capita, 80)

# We assigned a third variable GDP per capita, scaled_gdp_per_capita to the size parameters

colors = np.random.rand(8)

# we also assigned a random color to the bubbles to make it attractive and more understandable
print(colors)
# Out:
# [0.86869989 0.0955678  0.11891252 0.22498957 0.52676657 0.36775613
#  0.23185831 0.41592259]

# %%
plt.scatter(countries, populations, s=scaled_gdp_per_capita, c=colors, cmap="Blues",edgecolors="grey", alpha=0.5)

# Add X Label on X-axis
plt.xlabel("Countries")

# Add Y Label on X-axis
plt.ylabel("Population")

# Add title to graph
plt.title("Bubble Chart")

# rotate x label for clear visualization
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
plt.figure(figsize=(6,6))


sales  = np.divide(data.Sales, 80)


plt.scatter(data.TV, data.Sales, s=data.Radio, cmap="Blues",marker='*',edgecolors="pink", alpha=0.5)

# Add X Label on X-axis
plt.xlabel("Sales")

# Add Y Label on X-axis
plt.ylabel("Medios")

# Add title to graph
plt.title("Bubble Chart")

# rotate x label for clear visualization
plt.xticks(rotation=45)

# Show the plot
plt.show()
# Out:
# /var/folders/4z/x6shzw4x79sfhzq_fg7mr3180000gn/T/ipykernel_26627/3591271781.py:7: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(data.TV, data.Sales, s=data.Radio, cmap="Blues",marker='*',edgecolors="pink", alpha=0.5)

# %%
import seaborn as sns
data = sns.load_dataset("iris")

# Create a pair plot
sns.pairplot(data)

# Show figure
plt.show()
